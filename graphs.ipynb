# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_scaled = pd.read_csv('dataset_scaled.csv')
scores = pd.read_json('credit_scores.json')

# %%
dataset_scaled.hist(figsize=(10,14))
plt.savefig('figure1.png')
plt.show()

# %%
# Score graphs
scores['credit_score'].hist(bins=20)
plt.savefig('figure2.png')
plt.show()
